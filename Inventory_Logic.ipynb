# %%
import pandas as pd

# %%
df = pd.read_excel('Wawa Store 0853 - Asset Tag-Inventory Sheet - 1.1.20(2).xlsm',skiprows=14)

# %%
df.head(20)
# Out:
#                                           Lane/Number  \
# 0   Physical lane # or if n/a, count (ex. 2 for 2n...
# 1                                                 NaN
# 2                                                  01
# 3                                                  01
# 4                                                  01
# 5                                                  02
# 6                                                  01
# 7                                                  01
# 8                                                  01
# 9                                                 RWS
# 10                                                AMS
# 11                                                 01
# 12                                                 10
# 13                                                NaN
# 14                                                 11
# 15                                                NaN
# ...

# %%
d = {'1':'sdjkhfds','2':'dslkjec'}

# %%
print(d['1'])
# Out:
# sdjkhfds

# %%
from dictionary import TMP_DATA_FILE

# %%
TMP_DATA_FILE['a']
# Out:
# 'val1'
